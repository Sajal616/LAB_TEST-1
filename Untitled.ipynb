# %%
import numpy as np
totalsales = 0
inventory = np.array([['Medicine1',200,100],
                      ['Medicine2',100,200],
                      ['Medicine3',400,50],
                      ['Medicine4',40,60]])
def updateItem(name,sales):
    x=inventory[inventory[:,0]==name,2]
    print(x)
def addItem(name,price,quantity):
    inv = np.array([[name,price,quantity]])
    inventory = np.conjugate(inv)
addItem('Medicine5',20,70)
updateItem('Medicine1',20)
def displayInventory():
    print(inventory)
displayInventory()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[53], line 13
#      11     inv = np.array([[name,price,quantity]])
#      12     inventory = np.conjugate(inv)
# ---> 13 addItem('Medicine5',20,70)
#      14 updateItem('Medicine1',20)
#      15 def displayInventory():
#
# Cell In[53], line 12, in addItem(name, price, quantity)
#      10 def addItem(name,price,quantity):
#      11     inv = np.array([[name,price,quantity]])
# ---> 12     inventory = np.conjugate(inv)
#
# TypeError: ufunc 'conjugate' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''

# %%
import matplotlib.pyplot as plt
tsales = np.random.randint(1,100,200)
profit = np.random.randint(1,40,200)
plt.scatter(tsales,profit)
plt.xlabel("Total Sales")
plt.ylabel("Profit")
plt.show()
